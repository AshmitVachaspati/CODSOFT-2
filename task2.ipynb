# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_movie=pd.read_csv("/content/archive (3).zip", encoding='latin1')
df_movie.dropna(inplace=True)
display(df_movie.head())
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %%
df_movie.shape
# Out:
# (5659, 10)

# %%
df_movie.describe()
# Out:
#             Rating
# count  5659.000000
# mean      5.898533
# std       1.381165
# min       1.100000
# 25%       5.000000
# 50%       6.100000
# 75%       6.900000
# max      10.000000

# %%
df_movie.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df_ratings=pd.read_csv("/content/archive (3).zip", encoding='latin1')
df_ratings.dropna(inplace=True)
display(df_ratings.head())
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %%
df_ratings.shape
# Out:
# (5659, 10)

# %%
df_ratings.describe()
# Out:
#             Rating
# count  5659.000000
# mean      5.898533
# std       1.381165
# min       1.100000
# 25%       5.000000
# 50%       6.100000
# 75%       6.900000
# max      10.000000

# %%
df_ratings.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df_users=pd.read_csv("/content/archive (3).zip", encoding='latin1')
df_users.dropna(inplace=True)
display(df_users.head(10))
# Out:
#                                   Name    Year Duration  \
# 1   #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                              #Yaaram  (2019)  110 min
# 5                 ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                            ...Yahaan  (2005)  142 min
# 8                   ?: A Question Mark  (2012)   82 min
# 9                             @Andheri  (2014)  116 min
# 10           1:1.6 An Ode to Lost Love  (2004)   96 min
# 11                1:13:7 Ek Tera Saath  (2016)  120 min
# 12                            100 Days  (1991)  161 min
# 13                           100% Love  (2012)  166 min
#
#                         Genre  Rating  Votes           Director  \
# 1                       Drama     7.0      8      Gaurav Bakshi
# 3             Comedy, Romance     4.4     35         Ovais Khan
# 5      Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086     Shoojit Sircar
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df_users['Genre']=labelencoder.fit_transform(df_users['Genre'])
df_users.head()
# Out:
#                                  Name    Year Duration  Genre  Rating  Votes  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min    229     7.0      8
# 3                             #Yaaram  (2019)  110 min    184     4.4     35
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min    157     4.7    827
# 6                           ...Yahaan  (2005)  142 min    289     7.4  1,086
# 8                  ?: A Question Mark  (2012)   82 min    320     5.6    326
#
#          Director          Actor 1                 Actor 2          Actor 3
# 1   Gaurav Bakshi     Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 3      Ovais Khan          Prateik              Ishita Raj  Siddhant Kapoor
# 5    Rahul Rawail       Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6  Shoojit Sircar  Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 8   Allyson Patel        Yash Dave          Muntazir Ahmad     Kiran Bhatia

# %%
df_users.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df_data = pd.concat([df_movie,df_ratings,df_users],axis=1)
df_data.head(10)
# Out:
#                                   Name    Year Duration  \
# 1   #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                              #Yaaram  (2019)  110 min
# 5                 ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                            ...Yahaan  (2005)  142 min
# 8                   ?: A Question Mark  (2012)   82 min
# 9                             @Andheri  (2014)  116 min
# 10           1:1.6 An Ode to Lost Love  (2004)   96 min
# 11                1:13:7 Ek Tera Saath  (2016)  120 min
# 12                            100 Days  (1991)  161 min
# 13                           100% Love  (2012)  166 min
#
#                         Genre  Rating  Votes           Director  \
# 1                       Drama     7.0      8      Gaurav Bakshi
# 3             Comedy, Romance     4.4     35         Ovais Khan
# 5      Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086     Shoojit Sircar
# ...

# %%
df_data.shape
# Out:
# (5659, 30)

# %%
df.head()

# %%
df2.describe()
# Out:
#          Rating    Rating       Genre    Rating
# count  5.000000  5.000000    5.000000  5.000000
# mean   5.820000  5.820000  235.800000  5.820000
# std    1.342386  1.342386   68.663673  1.342386
# min    4.400000  4.400000  157.000000  4.400000
# 25%    4.700000  4.700000  184.000000  4.700000
# 50%    5.600000  5.600000  229.000000  5.600000
# 75%    7.000000  7.000000  289.000000  7.000000
# max    7.400000  7.400000  320.000000  7.400000

# %%
df2.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df_find = df_data.loc[:,~df_data.columns.duplicated()].dropna()

# %%
df_find.shape
# Out:
# (5, 30)

# %%
df_find.plot.hist(bins=25)
plt.ylabel("Name")
plt.xlabel("Rating")
# Out:
# Text(0.5, 0, 'Rating')

# %%
df_find['Rating'].value_counts().plot(kind='bar')
plt.show()

# %%
df_find['Rating'].plot.hist(bins=10)
plt.xlabel("Name")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
scaler=MinMaxScaler()
labelencoder=LabelEncoder()
df_find['Genre']=labelencoder.fit_transform(df_find['Genre'])
df_find['Votes'] = df_find['Votes'].str.replace(',', '').astype(float)
scaled_data=scaler.fit_transform(df_find[['Genre', 'Rating', 'Votes']])
scaled_df=pd.DataFrame(scaled_data,columns=['Genre', 'Rating', 'Votes'])
scaled_df.head()
# Out:
#       Genre    Rating     Votes
# 0  0.610667  0.662921  0.000005
# 1  0.490667  0.370787  0.000051
# 2  0.418667  0.404494  0.001390
# 3  0.770667  0.707865  0.001828
# 4  0.853333  0.505618  0.000543

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_df, df_find['Name'], test_size=0.2, random_state=42)

# %%
print(y_train)
# Out:
# 9424                                   Mmirsa
# 12009                                    Roti
# 4316                                  Eeshwar
# 6897                                  Junglee
# 2338                                   Bijuka
#                          ...
# 10263                                  Noorie
# 14280    The Untitled Kartik Krishnan Project
# 14355                               Time Pass
# 14818                        Veere Di Wedding
# 2209                         Bhayaanak Panjaa
# Name: Name, Length: 4527, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test=np.array(X_test)

# %%
model.predict(X_test)
# Out:
# array(['Badal', 'Zindagi', 'Zindagi', ..., 'Elaan', 'Zindagi', 'Zindagi'],
#       dtype=object)

# %%
print(y_test)
# Out:
# 10971                       Pratibandh
# 14052                    The Dirty MMS
# 10002                      Naseebwaala
# 3970                      Divya Shakti
# 8840                         Manjunath
#                      ...
# 13713    Taj Mahal: A Monument of Love
# 2820                   Chand Bujh Gaya
# 1810                           Bandhan
# 13679                             Taal
# 1649                      Badnam Basti
# Name: Name, Length: 1132, dtype: object
